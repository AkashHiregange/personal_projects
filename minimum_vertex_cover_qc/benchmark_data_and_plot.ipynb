# %% [markdown]
# __QAOA local simulator data__

# %%
time_of_execution = [20.560124158859253, 23.897254705429077, 40.689375162124634, 37.685121059417725, 51.26829648017883, 74.36467289924622,743.6304135322571, 5922.42140054702]
nodes = [5,7,9,11,13,15,17,23]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()
plt.plot(nodes, time_of_execution , color='r')
plt.scatter(nodes, time_of_execution , color='b')
plt.xlabel('Number of nodes (vertices)')
plt.ylabel('execution time in seconds')
plt.savefig('qaoa.png', dpi=300)
plt.grid(alpha=0.5)
plt.show()

# %% [markdown]
#  __From the HybridQCM sampler__

# %%
energy_5_nodes = [2,2,2,2,2,2]
percentage_of_occurences_5_nodes = [98/120,99/116,136/143,145/154,137/141,142/149]
time = [5,10,15,20,25,35]
energy_10_nodes = [5,5,5,5,5,5]
percentage_of_occurences_10_nodes = [99/127,98/128,140/155,149/155,119/152,133/149]
energy_20_nodes = [7,7,7,7,7,7]
percentage_of_occurences_20_nodes = [95/127,91/128,135/154,132/152,131/151,122/150]
energy_40_nodes = []
percentage_of_occurences_30_nodes = [92/126,83/128,125/153,112/151,124/151,108/132]
percentage_of_occurences_50_nodes = [89/126,86/128,134/152,130/149,130/148,113/132]
percentage_of_occurences_60_nodes = [88/126,96/127,136/152,136/149,135/148,119/132]
percentage_of_occurences_80_nodes = [83/126,86/127,115/150,123/148,118/145,106/132]
energy_80_nodes = []
energy_160_nodes = []

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()
plt.plot(time, np.array(percentage_of_occurences_5_nodes)*100, color='r', label='6 nodes (6 qubits)')
plt.plot(time, np.array(percentage_of_occurences_10_nodes)*100, color='b', label='10 nodes (10 qubits)')
plt.plot(time, np.array(percentage_of_occurences_20_nodes)*100, color='g', label='20 nodes (20 qubits)')
plt.plot(time, np.array(percentage_of_occurences_30_nodes)*100, color='orange', label='30 nodes (30 qubits)')
plt.plot(time, np.array(percentage_of_occurences_80_nodes)*100, color='magenta', label='80 nodes (80 qubits)')
# plt.plot(time, np.array(percentage_of_occurences_60_nodes)*100, color='purple', label='60 nodes (60 qubits)')
# plt.plot(time, np.array(percentage_of_occurences_70_nodes)*100, color='black', label='70 nodes (70 qubits)')
plt.legend()
plt.xlabel('time limit for CQM hybrid sampler (seconds)')
plt.ylabel('Percentage (%) of lowest energy feasible samples')
plt.grid(alpha=0.5)
plt.savefig('hybrid_benchmark.png', dpi=300)

plt.show()

# %%
arr = np.array([percentage_of_occurences_5_nodes,percentage_of_occurences_10_nodes,percentage_of_occurences_20_nodes,
               percentage_of_occurences_30_nodes,percentage_of_occurences_50_nodes,percentage_of_occurences_60_nodes,
                percentage_of_occurences_70_nodes])
print(arr.shape)
# Out:
# (7, 6)

# %%
fig = plt.figure()
nodes_hyb = [5,10,20,30,50,60,70]
plt.plot(nodes_hyb, arr[:,0], color='r', label='5 s')
plt.plot(nodes_hyb, arr[:,1], color='b', label='10 s')
plt.plot(nodes_hyb, arr[:,2], color='g', label='15 s')
plt.plot(nodes_hyb, arr[:,3], color='orange', label='20 s')
plt.plot(nodes_hyb, arr[:,4], color='magenta', label='30 s')
plt.plot(nodes_hyb, arr[:,5], color='purple', label='35 s)')

plt.legend()
plt.xlabel('Number of nodes (qubits)')
plt.ylabel('Percentage (%) of feasible samples')
plt.grid(alpha=0.5)
plt.savefig('hybrid_benchmark_convergence.png', dpi=300)

plt.show()

# %% [markdown]
# __From the QUBO sampler__

# %%
time_of_execution_qubo = [182.76,252.6,208.04,253.2,248.32,267.52,312.88,399.72]
nodes_qubo = [5,10,20,40,60,80,100,120]

# %%
fig, ax1 = plt.subplots()


ax1.set_xlabel('Number of nodes (qubits)')
ax1.set_ylabel('execution time (s) for QAOA using local simulator', color='r')
ax1.plot(nodes, time_of_execution, color='r', label='QAOA (Local simulator)')
# ax1.scatter(nodes, time_of_execution, color='orange')
ax1.tick_params(axis='y', labelcolor='r')
ax1.grid(alpha=0.5)
# plt.legend()
ax2 = ax1.twinx()  # instantiate a second Axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('execution time (ms) for Quantum annealer', color='g')  # we already handled the x-label with ax1
ax2.plot(nodes_qubo, time_of_execution_qubo, color='g', label='Quantum annealer')
# ax2.scatter(nodes_qubo, time_of_execution_qubo, color='b')
ax2.tick_params(axis='y', labelcolor='g')
fig.legend(loc='upper center')

# fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.savefig('qaoa.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# fig = plt.figure()
# plt.plot(nodes, time_of_execution , color='r')
# plt.scatter(nodes, time_of_execution , color='b')
# plt.xlabel('Number of nodes (vertices)')
# plt.ylabel('execution time in seconds')
# plt.savefig('qaoa.png', dpi=300)
# plt.show()
